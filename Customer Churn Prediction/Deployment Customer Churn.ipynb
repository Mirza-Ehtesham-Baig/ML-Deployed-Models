# %%
pip install gradio
# Out:
# ...
#   Obtaining dependency information for gradio from https://files.pythonhosted.org/packages/94/e6/48f65e81840f83aec83a805a60f81cbd60d85de6d2e6d6dc604217fdc6d5/gradio-4.27.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for altair<6.0,>=4.2.0 from https://files.pythonhosted.org/packages/46/30/2118537233fa72c1d91a81f5908a7e843a6601ccc68b76838ebc4951505f/altair-5.3.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fastapi from https://files.pythonhosted.org/packages/ad/0f/feb7fd8957714498fc4a6be7f13408869619f868f418698a2d934afa82a7/fastapi-0.110.2-py3-none-any.whl.metadata
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Obtaining dependency information for gradio-client==0.15.1 from https://files.pythonhosted.org/packages/12/99/433f90d17d24738ed795b7c9b78ba1e4149b97a8dfe927e2f6e5f537d541/gradio_client-0.15.1-py3-none-any.whl.metadata
# ...

# %%
import gradio as gr
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
# Load a trained model in this file

with open('final_model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# %%
# Prediction Function

def prediction(CreditScore,Geography,Age,Tenure,Balance,NumOfProducts,HasCrCard,IsActiveMember,EstimatedSalary,Gender):
    input_data = [[CreditScore,Geography,Age,Tenure,Balance,NumOfProducts,HasCrCard,IsActiveMember,EstimatedSalary,Gender]]
    pred = loaded_model.predict(input_data)[0]
    if pred == 0:
        return 'Not at Risk'
    else:
        return 'At Risk'

# %%
prediction(631,2227,46,9,160736.63,1,0,1,93503.02,1)
# Out:
# 'Not at Risk'

# %%
# Interface
iface=gr.Interface(fn=prediction,
                  inputs=[gr.Number(label='Enter the Credict Score'),
                         gr.Dropdown([('France',4522),('Germany',2255),('Spain',2223)],label='Select Country'),
                         gr.Slider(minimum=18,maximum=100,step=1,label='Select Age'),
                         gr.Number(label='Enter Tenure'),
                         gr.Number(label='Enter Balance in Acount'),
                         gr.Dropdown([1,2,3,4],label='Enter Number of Products With Customer'),
                         gr.Dropdown([('Yes',1),('No',0)],label='Does Customer has Credit Card'),
                         gr.Dropdown([('Yes',1),('No',0)],label='Is Customer An Active Member?'),
                         gr.Number(label='What is the Estimated Salary of the Customer?'),
                         gr.Dropdown([('Male',1),('Female',0)],label='Select Gender')],
                  outputs= gr.Textbox(label='Status'),
                  title='Hyderabad Cooperative Bank',
                  description='Enter the details of the Customer to check Status',
                  allow_flagging='never')

# %%
iface.launch(share=True)
# Out:
# Rerunning server... use `close()` to stop if you need to change `launch()` parameters.
# ----
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\gradio\networking.py:42, in setup_tunnel(local_host, local_port, share_token, share_server_address)
#      41 tunnel = Tunnel(remote_host, remote_port, local_host, local_port, share_token)
# ---> 42 address = tunnel.start_tunnel()
#      43 return address
#
# File ~\anaconda3\Lib\site-packages\gradio\tunneling.py:67, in Tunnel.start_tunnel(self)
#      66 self.download_binary()
# ---> 67 self.url = self._start_tunnel(BINARY_PATH)
#      68 return self.url
#
# File ~\anaconda3\Lib\site-packages\gradio\tunneling.py:95, in Tunnel._start_tunnel(self, binary)
#      78 command = [
#      79     binary,
#      80     "http",
#    (...)
#      93     "--disable_log_color",
#      94 ]
# ...
